# %% [markdown]
# # Data Science Tools and Ecosystem #

# %% [markdown]
# ## By Néstor Tajuelo Arjona

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# We will explore several of the most important aspects of Data Science, involving:
# 1) Programming Languages
# 2) Libraries
# 3) Tools

# %% [markdown]
# Some of the most popular programming languages that Data Scientists use are:
# 1. R
# 2. Python
# 3. SQL

# %% [markdown]
# Some of the most important libraries that Data Scientists use are:
# 1. ggplot2
# 2. matplotlib
# 3. pandas

# %%
| Data Science Tools         |
|----------------------------|
| Jupyter Notebook           |
| RStudio                    |
| Visual Studio Code (VSCode)|

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %%
# This is a simple example for multiplying and adding integers
(3*4)+5
# Out:
# 17

# %%
# This is an expression to change the format of hours into minutes
200 / 60
# Out:
# 3.3333333333333335
